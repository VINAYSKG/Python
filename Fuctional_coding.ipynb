# %% [markdown]
# <a href="https://colab.research.google.com/github/VINAYSKG/Python/blob/main/Fuctional_coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#functions-Block of code:-(a)Functional coding (b)procedural coding

# %%
def name():
  print('Vinay')

# %%
name()
# Out:
# Vinay

# %%
def add(x,y):
  c=x+y
  return c

# %%
add(3,4)
# Out:
# 7

# %%
def table(a):
  for i in range(1,11):
    print(a*i)

# %%
#cal
table(3)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
#global variable
x='global'
def chk_global():
  print(x+"var")

# %%
chk_global()
print(x)
# Out:
# globalvar
# global

# %%
#local variable
def chk_local():
  x1=10
  print(x1)

# %%
chk_local()
print(x1)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1927449765.py in <cell line: 0>()
#       1 chk_local()
# ----> 2 print(x1)
#
# NameError: name 'x1' is not defined
